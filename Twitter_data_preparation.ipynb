# %% [markdown]
# <a href="https://colab.research.google.com/github/Rohan-Kumar-Singh/Sentiment-analysis-of-informal-text/blob/master/Twitter_data_preparation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

df = pd.read_csv('/content/drive/MyDrive/major-final/new_tweets/Bollywood_Hindi.csv')
print(df) 

df1 = pd.read_csv('/content/drive/MyDrive/major-final/new_tweets/Covid_Hindi.csv')
print(df1)

df2 = pd.read_csv('/content/drive/MyDrive/major-final/new_tweets/Election_Hindi.csv')
print(df2)

df3 = pd.read_csv('/content/drive/MyDrive/major-final/new_tweets/IPL_Hindi.csv')
print(df3)

df4 = pd.read_csv('/content/drive/MyDrive/major-final/new_tweets/Meme_Hindi.csv')
print(df4)

df5 = pd.read_csv('/content/drive/MyDrive/major-final/new_tweets/Riots_Hindi.csv')
print(df5)

df6 = pd.read_csv('/content/drive/MyDrive/major-final/new_tweets/Youtube_Hindi.csv')
print(df6)

df7 = pd.read_csv('/content/drive/MyDrive/major-final/new_tweets/News_Hindi.csv')
print(df7)



pd.concat([df,df1,df2,df3,df4,df5,df6,df7]).to_csv('twitter_data_hi.csv', index=False )
# Out:
#                  User                                              Tweet
# 0       TanseemHaider  RT @aajtak: जैकलीन फर्नांडीस ने कोर्ट से 15 दि...
# 1      sanjayyadav782  RT @OpIndia_in: ‘बॉलीवुड मुझे अफॉर्ड नहीं कर स...
# 2        chetanjoshi_  RT @thepaltan_: संवेदनशील मुद्दों पर सृजनात्मक...
# 3          thepaltan_  संवेदनशील मुद्दों पर सृजनात्मक प्रहार करता सिन...
# 4        RajivSanatni  RT @rowdy_pandit: 💥जब दिखेगा तभी तो बिकेगा!!🤓🙂...
# ...               ...                                                ...
# 2995  pravindyadav_WB  RT @TheSachai: #ThankfulTuesday कम से कम हिजाब...
# 2996         i_pallvi  रहस्यमयी संगठन #इल्युमिनाटी पर बनेगी म्यूजिकल ...
# 2997  sarojinisahusa1  RT @abpmajhatv: #EntertainmentNews : अभिनेत्री...
# 2998     BintuMeena16  RT @aajtak: साउथ के सुपरस्टार महेश बाबू अपने ए...
# 2999    jay_khiladism  @HimeshMankad Kya yrr bollywood vale hi khud s...
#
# [3000 rows x 2 columns]
# ...

# %%
import pandas as pd

df = pd.read_csv('/content/drive/MyDrive/major-final/new_tweets/Bollywood_English.csv')
print(df) 

df1 = pd.read_csv('/content/drive/MyDrive/major-final/new_tweets/Covid_English.csv')
print(df1)

df2 = pd.read_csv('/content/drive/MyDrive/major-final/new_tweets/IPL_English.csv')
print(df2)

df3 = pd.read_csv('/content/drive/MyDrive/major-final/new_tweets/Meme_English.csv')
print(df3)

df4 = pd.read_csv('/content/drive/MyDrive/major-final/new_tweets/Riots_English.csv')
print(df4)

df5 = pd.read_csv('/content/drive/MyDrive/major-final/new_tweets/Youtube_English.csv')
print(df5)

df6 = pd.read_csv('/content/drive/MyDrive/major-final/new_tweets/Election_English.csv')
print(df5)

df7 = pd.read_csv('/content/drive/MyDrive/major-final/new_tweets/News_English.csv')
print(df5)



pd.concat([df,df1,df2,df3,df4,df5,df6,df7]).to_csv('twitter_data_en.csv', index=False )
# Out:
#                  User                                              Tweet
# 0         Ephraim0324  RT @dna: #Cannes2022 | #HinaKhan to return to ...
# 1      Moonsroofindia  Farah Khan is funny. “Khaali Peeli,” which Ana...
# 2     janisarSSR_2020  RT @Dipikak74365413: @ATUL7735 @Jannat_Firdous...
# 3              ls2008  RT @Sassy_Hindu: J&amp;K: The ASI objects to a...
# 4        imtruelegend  RT @Ashish81618033: @AdvAshutoshBJP I think ne...
# ...               ...                                                ...
# 2995         Ritwij10  @gauranggor @mayankkunjean @RajKeplerhume Maha...
# 2996      MadhavYoung  RT @Showbiz_IT: #Runway34 box office collectio...
# 2997         anua1118  RT @sarcasticnimitt: Some bollywood movies sug...
# 2998  XIlbrTPQMl5IxGK  RT @Sassy_Hindu: J&amp;K: The ASI objects to a...
# 2999     ShyamDHFM117  @thinker_piyush Yes bro,but media is asking so...
#
# [3000 rows x 2 columns]
# ...

# %%
dfhi = pd.read_csv('/content/twitter_data_hi.csv')
dfhi
# Out:
#                   User                                              Tweet
# 0        TanseemHaider  RT @aajtak: जैकलीन फर्नांडीस ने कोर्ट से 15 दि...
# 1       sanjayyadav782  RT @OpIndia_in: ‘बॉलीवुड मुझे अफॉर्ड नहीं कर स...
# 2         chetanjoshi_  RT @thepaltan_: संवेदनशील मुद्दों पर सृजनात्मक...
# 3           thepaltan_  संवेदनशील मुद्दों पर सृजनात्मक प्रहार करता सिन...
# 4         RajivSanatni  RT @rowdy_pandit: 💥जब दिखेगा तभी तो बिकेगा!!🤓🙂...
# ...                ...                                                ...
# 21995  RajkumaarPandey  RT @archana_datar: @RajkumaarPandey @Avdheshan...
# 21996  KaranPa81828415  RT @SatlokChannel: घाटी में जन्में सन्तूर सम्र...
# 21997  Sumit_Sangwan20  RT @VinodAgnihotri7: पत्रकारिता के प्रति समर्प...
# 21998  KaranPa76501294  RT @SatlokChannel: घाटी में जन्में सन्तूर सम्र...
# 21999  KaranPa29417108  RT @SatlokChannel: घाटी में जन्में सन्तूर सम्र...
#
# [22000 rows x 2 columns]
# ...

# %%
dfen = pd.read_csv('/content/twitter_data_en.csv',lineterminator='\n')
dfen
# Out:
#                   User                                              Tweet
# 0          Ephraim0324  RT @dna: #Cannes2022 | #HinaKhan to return to ...
# 1       Moonsroofindia  Farah Khan is funny. “Khaali Peeli,” which Ana...
# 2      janisarSSR_2020  RT @Dipikak74365413: @ATUL7735 @Jannat_Firdous...
# 3               ls2008  RT @Sassy_Hindu: J&amp;K: The ASI objects to a...
# 4         imtruelegend  RT @Ashish81618033: @AdvAshutoshBJP I think ne...
# ...                ...                                                ...
# 21995  gordonm25443977  RT @toryman1979: https://t.co/QDwRYKgtm7\nTwin...
# 21996      backflipken  RT @ABSCBNNews: SB19's Ken postpones release o...
# 21997     phorlerkemii  RT @Gistloversblog1: The comment I was looking...
# 21998  Yashika_SidNaaz  RT @filmibeat: Tejasswi Prakash, Shehnaaz Gill...
# 21999        WediRaya7  RT @E2buddy1: On this #MothersDay2022 Tigrayan...
#
# [22000 rows x 2 columns]

# %%
import re

def RemoveMentions(tweet):
    tweet_ = re.sub(r"@\S+", "", tweet)
    return tweet_

dfhi["removed_mentions"] = dfhi["Tweet"].apply(RemoveMentions)
dfhi
# Out:
#                   User                                              Tweet  \
# 0        TanseemHaider  RT @aajtak: जैकलीन फर्नांडीस ने कोर्ट से 15 दि...
# 1       sanjayyadav782  RT @OpIndia_in: ‘बॉलीवुड मुझे अफॉर्ड नहीं कर स...
# 2         chetanjoshi_  RT @thepaltan_: संवेदनशील मुद्दों पर सृजनात्मक...
# 3           thepaltan_  संवेदनशील मुद्दों पर सृजनात्मक प्रहार करता सिन...
# 4         RajivSanatni  RT @rowdy_pandit: 💥जब दिखेगा तभी तो बिकेगा!!🤓🙂...
# ...                ...                                                ...
# 21995  RajkumaarPandey  RT @archana_datar: @RajkumaarPandey @Avdheshan...
# 21996  KaranPa81828415  RT @SatlokChannel: घाटी में जन्में सन्तूर सम्र...
# 21997  Sumit_Sangwan20  RT @VinodAgnihotri7: पत्रकारिता के प्रति समर्प...
# 21998  KaranPa76501294  RT @SatlokChannel: घाटी में जन्में सन्तूर सम्र...
# 21999  KaranPa29417108  RT @SatlokChannel: घाटी में जन्में सन्तूर सम्र...
#
#                                         removed_mentions
# ...

# %%
import re

def RemoveMentions(tweet):
    tweet_ = re.sub(r"@\S+", "", tweet)
    return tweet_

dfen["removed_mentions"] = dfen["Tweet"].apply(RemoveMentions)
dfen
# Out:
#                   User                                              Tweet  \
# 0          Ephraim0324  RT @dna: #Cannes2022 | #HinaKhan to return to ...
# 1       Moonsroofindia  Farah Khan is funny. “Khaali Peeli,” which Ana...
# 2      janisarSSR_2020  RT @Dipikak74365413: @ATUL7735 @Jannat_Firdous...
# 3               ls2008  RT @Sassy_Hindu: J&amp;K: The ASI objects to a...
# 4         imtruelegend  RT @Ashish81618033: @AdvAshutoshBJP I think ne...
# ...                ...                                                ...
# 21995  gordonm25443977  RT @toryman1979: https://t.co/QDwRYKgtm7\nTwin...
# 21996      backflipken  RT @ABSCBNNews: SB19's Ken postpones release o...
# 21997     phorlerkemii  RT @Gistloversblog1: The comment I was looking...
# 21998  Yashika_SidNaaz  RT @filmibeat: Tejasswi Prakash, Shehnaaz Gill...
# 21999        WediRaya7  RT @E2buddy1: On this #MothersDay2022 Tigrayan...
#
#                                         removed_mentions
# ...

# %%
import string

punctuations_list = string.punctuation

def RemovePunctuations(text):
    transformator = str.maketrans('', '', punctuations_list)
    return text.translate(transformator)

dfhi["removed_punct"] = dfhi["removed_mentions"].apply(RemovePunctuations)
dfhi
# Out:
#                   User                                              Tweet  \
# 0        TanseemHaider  RT @aajtak: जैकलीन फर्नांडीस ने कोर्ट से 15 दि...
# 1       sanjayyadav782  RT @OpIndia_in: ‘बॉलीवुड मुझे अफॉर्ड नहीं कर स...
# 2         chetanjoshi_  RT @thepaltan_: संवेदनशील मुद्दों पर सृजनात्मक...
# 3           thepaltan_  संवेदनशील मुद्दों पर सृजनात्मक प्रहार करता सिन...
# 4         RajivSanatni  RT @rowdy_pandit: 💥जब दिखेगा तभी तो बिकेगा!!🤓🙂...
# ...                ...                                                ...
# 21995  RajkumaarPandey  RT @archana_datar: @RajkumaarPandey @Avdheshan...
# 21996  KaranPa81828415  RT @SatlokChannel: घाटी में जन्में सन्तूर सम्र...
# 21997  Sumit_Sangwan20  RT @VinodAgnihotri7: पत्रकारिता के प्रति समर्प...
# 21998  KaranPa76501294  RT @SatlokChannel: घाटी में जन्में सन्तूर सम्र...
# 21999  KaranPa29417108  RT @SatlokChannel: घाटी में जन्में सन्तूर सम्र...
#
#                                         removed_mentions  \
# ...

# %%
import string

punctuations_list = string.punctuation

def RemovePunctuations(text):
    transformator = str.maketrans('', '', punctuations_list)
    return text.translate(transformator)

dfen["removed_punct"] = dfen["removed_mentions"].apply(RemovePunctuations)
dfen
# Out:
#                   User                                              Tweet  \
# 0          Ephraim0324  RT @dna: #Cannes2022 | #HinaKhan to return to ...
# 1       Moonsroofindia  Farah Khan is funny. “Khaali Peeli,” which Ana...
# 2      janisarSSR_2020  RT @Dipikak74365413: @ATUL7735 @Jannat_Firdous...
# 3               ls2008  RT @Sassy_Hindu: J&amp;K: The ASI objects to a...
# 4         imtruelegend  RT @Ashish81618033: @AdvAshutoshBJP I think ne...
# ...                ...                                                ...
# 21995  gordonm25443977  RT @toryman1979: https://t.co/QDwRYKgtm7\nTwin...
# 21996      backflipken  RT @ABSCBNNews: SB19's Ken postpones release o...
# 21997     phorlerkemii  RT @Gistloversblog1: The comment I was looking...
# 21998  Yashika_SidNaaz  RT @filmibeat: Tejasswi Prakash, Shehnaaz Gill...
# 21999        WediRaya7  RT @E2buddy1: On this #MothersDay2022 Tigrayan...
#
#                                         removed_mentions  \
# ...

# %%
def RemoveLinks(text):
    return re.sub(r"http\S+", "", text)

dfhi["removed_links"] = dfhi["removed_punct"].apply(RemoveLinks)
dfhi
# Out:
#                   User                                              Tweet  \
# 0        TanseemHaider  RT @aajtak: जैकलीन फर्नांडीस ने कोर्ट से 15 दि...
# 1       sanjayyadav782  RT @OpIndia_in: ‘बॉलीवुड मुझे अफॉर्ड नहीं कर स...
# 2         chetanjoshi_  RT @thepaltan_: संवेदनशील मुद्दों पर सृजनात्मक...
# 3           thepaltan_  संवेदनशील मुद्दों पर सृजनात्मक प्रहार करता सिन...
# 4         RajivSanatni  RT @rowdy_pandit: 💥जब दिखेगा तभी तो बिकेगा!!🤓🙂...
# ...                ...                                                ...
# 21995  RajkumaarPandey  RT @archana_datar: @RajkumaarPandey @Avdheshan...
# 21996  KaranPa81828415  RT @SatlokChannel: घाटी में जन्में सन्तूर सम्र...
# 21997  Sumit_Sangwan20  RT @VinodAgnihotri7: पत्रकारिता के प्रति समर्प...
# 21998  KaranPa76501294  RT @SatlokChannel: घाटी में जन्में सन्तूर सम्र...
# 21999  KaranPa29417108  RT @SatlokChannel: घाटी में जन्में सन्तूर सम्र...
#
#                                         removed_mentions  \
# ...

# %%
def RemoveLinks(text):
    return re.sub(r"http\S+", "", text)

dfen["removed_links"] = dfen["removed_punct"].apply(RemoveLinks)
dfen
# Out:
#                   User                                              Tweet  \
# 0          Ephraim0324  RT @dna: #Cannes2022 | #HinaKhan to return to ...
# 1       Moonsroofindia  Farah Khan is funny. “Khaali Peeli,” which Ana...
# 2      janisarSSR_2020  RT @Dipikak74365413: @ATUL7735 @Jannat_Firdous...
# 3               ls2008  RT @Sassy_Hindu: J&amp;K: The ASI objects to a...
# 4         imtruelegend  RT @Ashish81618033: @AdvAshutoshBJP I think ne...
# ...                ...                                                ...
# 21995  gordonm25443977  RT @toryman1979: https://t.co/QDwRYKgtm7\nTwin...
# 21996      backflipken  RT @ABSCBNNews: SB19's Ken postpones release o...
# 21997     phorlerkemii  RT @Gistloversblog1: The comment I was looking...
# 21998  Yashika_SidNaaz  RT @filmibeat: Tejasswi Prakash, Shehnaaz Gill...
# 21999        WediRaya7  RT @E2buddy1: On this #MothersDay2022 Tigrayan...
#
#                                         removed_mentions  \
# ...

# %%
def RemoveNumbers(text):       
    return re.sub(r"[0-9]+", "", text)

dfhi["removed_numbers"] = dfhi["removed_links"].apply(RemoveNumbers)
dfhi
# Out:
#                   User                                              Tweet  \
# 0        TanseemHaider  RT @aajtak: जैकलीन फर्नांडीस ने कोर्ट से 15 दि...
# 1       sanjayyadav782  RT @OpIndia_in: ‘बॉलीवुड मुझे अफॉर्ड नहीं कर स...
# 2         chetanjoshi_  RT @thepaltan_: संवेदनशील मुद्दों पर सृजनात्मक...
# 3           thepaltan_  संवेदनशील मुद्दों पर सृजनात्मक प्रहार करता सिन...
# 4         RajivSanatni  RT @rowdy_pandit: 💥जब दिखेगा तभी तो बिकेगा!!🤓🙂...
# ...                ...                                                ...
# 21995  RajkumaarPandey  RT @archana_datar: @RajkumaarPandey @Avdheshan...
# 21996  KaranPa81828415  RT @SatlokChannel: घाटी में जन्में सन्तूर सम्र...
# 21997  Sumit_Sangwan20  RT @VinodAgnihotri7: पत्रकारिता के प्रति समर्प...
# 21998  KaranPa76501294  RT @SatlokChannel: घाटी में जन्में सन्तूर सम्र...
# 21999  KaranPa29417108  RT @SatlokChannel: घाटी में जन्में सन्तूर सम्र...
#
#                                         removed_mentions  \
# ...

# %%
def RemoveNumbers(text):       
    return re.sub(r"[0-9]+", "", text)

dfen["removed_numbers"] = dfen["removed_links"].apply(RemoveNumbers)
dfen
# Out:
#                   User                                              Tweet  \
# 0          Ephraim0324  RT @dna: #Cannes2022 | #HinaKhan to return to ...
# 1       Moonsroofindia  Farah Khan is funny. “Khaali Peeli,” which Ana...
# 2      janisarSSR_2020  RT @Dipikak74365413: @ATUL7735 @Jannat_Firdous...
# 3               ls2008  RT @Sassy_Hindu: J&amp;K: The ASI objects to a...
# 4         imtruelegend  RT @Ashish81618033: @AdvAshutoshBJP I think ne...
# ...                ...                                                ...
# 21995  gordonm25443977  RT @toryman1979: https://t.co/QDwRYKgtm7\nTwin...
# 21996      backflipken  RT @ABSCBNNews: SB19's Ken postpones release o...
# 21997     phorlerkemii  RT @Gistloversblog1: The comment I was looking...
# 21998  Yashika_SidNaaz  RT @filmibeat: Tejasswi Prakash, Shehnaaz Gill...
# 21999        WediRaya7  RT @E2buddy1: On this #MothersDay2022 Tigrayan...
#
#                                         removed_mentions  \
# ...

# %%
dfhi['cleaned_tweets'] = dfhi['removed_numbers'].replace(r'\n',' ', regex=True) 
dfhi
# Out:
#                   User                                              Tweet  \
# 0        TanseemHaider  RT @aajtak: जैकलीन फर्नांडीस ने कोर्ट से 15 दि...
# 1       sanjayyadav782  RT @OpIndia_in: ‘बॉलीवुड मुझे अफॉर्ड नहीं कर स...
# 2         chetanjoshi_  RT @thepaltan_: संवेदनशील मुद्दों पर सृजनात्मक...
# 3           thepaltan_  संवेदनशील मुद्दों पर सृजनात्मक प्रहार करता सिन...
# 4         RajivSanatni  RT @rowdy_pandit: 💥जब दिखेगा तभी तो बिकेगा!!🤓🙂...
# ...                ...                                                ...
# 21995  RajkumaarPandey  RT @archana_datar: @RajkumaarPandey @Avdheshan...
# 21996  KaranPa81828415  RT @SatlokChannel: घाटी में जन्में सन्तूर सम्र...
# 21997  Sumit_Sangwan20  RT @VinodAgnihotri7: पत्रकारिता के प्रति समर्प...
# 21998  KaranPa76501294  RT @SatlokChannel: घाटी में जन्में सन्तूर सम्र...
# 21999  KaranPa29417108  RT @SatlokChannel: घाटी में जन्में सन्तूर सम्र...
#
#                                         removed_mentions  \
# ...

# %%
dfen['cleaned_tweets'] = dfen['removed_numbers'].replace(r'\n',' ', regex=True) 
dfen
# Out:
#                   User                                              Tweet  \
# 0          Ephraim0324  RT @dna: #Cannes2022 | #HinaKhan to return to ...
# 1       Moonsroofindia  Farah Khan is funny. “Khaali Peeli,” which Ana...
# 2      janisarSSR_2020  RT @Dipikak74365413: @ATUL7735 @Jannat_Firdous...
# 3               ls2008  RT @Sassy_Hindu: J&amp;K: The ASI objects to a...
# 4         imtruelegend  RT @Ashish81618033: @AdvAshutoshBJP I think ne...
# ...                ...                                                ...
# 21995  gordonm25443977  RT @toryman1979: https://t.co/QDwRYKgtm7\nTwin...
# 21996      backflipken  RT @ABSCBNNews: SB19's Ken postpones release o...
# 21997     phorlerkemii  RT @Gistloversblog1: The comment I was looking...
# 21998  Yashika_SidNaaz  RT @filmibeat: Tejasswi Prakash, Shehnaaz Gill...
# 21999        WediRaya7  RT @E2buddy1: On this #MothersDay2022 Tigrayan...
#
#                                         removed_mentions  \
# ...

# %%
dfhi=dfhi.drop(['removed_mentions', 'removed_punct', 'removed_links', 'removed_numbers'], axis = 1)
dfhi
# Out:
#                   User                                              Tweet  \
# 0        TanseemHaider  RT @aajtak: जैकलीन फर्नांडीस ने कोर्ट से 15 दि...
# 1       sanjayyadav782  RT @OpIndia_in: ‘बॉलीवुड मुझे अफॉर्ड नहीं कर स...
# 2         chetanjoshi_  RT @thepaltan_: संवेदनशील मुद्दों पर सृजनात्मक...
# 3           thepaltan_  संवेदनशील मुद्दों पर सृजनात्मक प्रहार करता सिन...
# 4         RajivSanatni  RT @rowdy_pandit: 💥जब दिखेगा तभी तो बिकेगा!!🤓🙂...
# ...                ...                                                ...
# 21995  RajkumaarPandey  RT @archana_datar: @RajkumaarPandey @Avdheshan...
# 21996  KaranPa81828415  RT @SatlokChannel: घाटी में जन्में सन्तूर सम्र...
# 21997  Sumit_Sangwan20  RT @VinodAgnihotri7: पत्रकारिता के प्रति समर्प...
# 21998  KaranPa76501294  RT @SatlokChannel: घाटी में जन्में सन्तूर सम्र...
# 21999  KaranPa29417108  RT @SatlokChannel: घाटी में जन्में सन्तूर सम्र...
#
#                                           cleaned_tweets
# ...

# %%
dfen=dfen.drop(['removed_mentions', 'removed_punct', 'removed_links', 'removed_numbers'], axis = 1)
dfen
# Out:
#                   User                                              Tweet  \
# 0          Ephraim0324  RT @dna: #Cannes2022 | #HinaKhan to return to ...
# 1       Moonsroofindia  Farah Khan is funny. “Khaali Peeli,” which Ana...
# 2      janisarSSR_2020  RT @Dipikak74365413: @ATUL7735 @Jannat_Firdous...
# 3               ls2008  RT @Sassy_Hindu: J&amp;K: The ASI objects to a...
# 4         imtruelegend  RT @Ashish81618033: @AdvAshutoshBJP I think ne...
# ...                ...                                                ...
# 21995  gordonm25443977  RT @toryman1979: https://t.co/QDwRYKgtm7\nTwin...
# 21996      backflipken  RT @ABSCBNNews: SB19's Ken postpones release o...
# 21997     phorlerkemii  RT @Gistloversblog1: The comment I was looking...
# 21998  Yashika_SidNaaz  RT @filmibeat: Tejasswi Prakash, Shehnaaz Gill...
# 21999        WediRaya7  RT @E2buddy1: On this #MothersDay2022 Tigrayan...
#
#                                           cleaned_tweets
# ...

# %%
print("For Hindi Dataframe")

print("The number of unique values of the text feature is {}".format(dfhi['cleaned_tweets'].nunique()))
print("The total number of rows in our dataframe is : {}".format(len(dfhi)))
print("The number of duplicated rows in our dataframe is : {}".format(len(dfhi)-dfhi['cleaned_tweets'].nunique()))
duplicate = dfhi[dfhi.duplicated('cleaned_tweets')]
 
print("Duplicate Rows :")
 
# Print the resultant Dataframe
duplicate
# Out:
# For Hindi Dataframe
# The number of unique values of the text feature is 10775
# The total number of rows in our dataframe is : 22000
# The number of duplicated rows in our dataframe is : 11225
# Duplicate Rows :
#                   User                                              Tweet  \
# 5      RakeshHindu1990  RT @OpIndia_in: ‘बॉलीवुड मुझे अफॉर्ड नहीं कर स...
# 6           ashu21ster  RT @OpIndia_in: ‘बॉलीवुड मुझे अफॉर्ड नहीं कर स...
# 10      Anilpandey6606  RT @OpIndia_in: ‘बॉलीवुड मुझे अफॉर्ड नहीं कर स...
# 18           Shubh2i50  RT @OpIndia_in: ‘बॉलीवुड मुझे अफॉर्ड नहीं कर स...
# 27         Raj20884918  RT @OpIndia_in: दक्षिण भारतीय कलाकार पैसों से ...
# ...                ...                                                ...
# 21995  RajkumaarPandey  RT @archana_datar: @RajkumaarPandey @Avdheshan...
# 21996  KaranPa81828415  RT @SatlokChannel: घाटी में जन्में सन्तूर सम्र...
# 21997  Sumit_Sangwan20  RT @VinodAgnihotri7: पत्रकारिता के प्रति समर्प...
# ...

# %%
dfhi = dfhi.drop_duplicates(subset='cleaned_tweets', keep='first')
dfhi
# Out:
#                   User                                              Tweet  \
# 0        TanseemHaider  RT @aajtak: जैकलीन फर्नांडीस ने कोर्ट से 15 दि...
# 1       sanjayyadav782  RT @OpIndia_in: ‘बॉलीवुड मुझे अफॉर्ड नहीं कर स...
# 2         chetanjoshi_  RT @thepaltan_: संवेदनशील मुद्दों पर सृजनात्मक...
# 3           thepaltan_  संवेदनशील मुद्दों पर सृजनात्मक प्रहार करता सिन...
# 4         RajivSanatni  RT @rowdy_pandit: 💥जब दिखेगा तभी तो बिकेगा!!🤓🙂...
# ...                ...                                                ...
# 21983  rajkuma97966159  RT @SudarshanNewsTV: संजय राउत को पोपट बताते ब...
# 21984   PredeepSharma2  RT @SatlokChannel: प्रत्येक वर्ष 25 अप्रैल को ...
# 21987   PredeepSharma2  RT @SatlokChannel: संत रामपाल जी महाराज के अनु...
# 21988   PredeepSharma2  RT @SatlokChannel: Twitter कम्पनी ने Elon musk...
# 21991     ZeeBiharNews  #Purnea- बाल सुधार गृह से 11 बाल कैदी फरार | #...
#
#                                           cleaned_tweets
# ...

# %%
print("For English Dataframe")

print("The number of unique values of the text feature is {}".format(dfen['cleaned_tweets'].nunique()))
print("The total number of rows in our dataframe is : {}".format(len(dfen)))
print("The number of duplicated rows in our dataframe is : {}".format(len(dfen)-dfen['cleaned_tweets'].nunique()))

duplicate = dfen[dfen.duplicated('cleaned_tweets')]
 
print("Duplicate Rows :")
 
# Print the resultant Dataframe
duplicate
# Out:
# For English Dataframe
# The number of unique values of the text feature is 10438
# The total number of rows in our dataframe is : 22000
# The number of duplicated rows in our dataframe is : 11562
# Duplicate Rows :
#                   User                                              Tweet  \
# 6      saurabhakkkkian  RT @dna: #Cannes2022 | #HinaKhan to return to ...
# 9      shittypolitians  RT @Sassy_Hindu: J&amp;K: The ASI objects to a...
# 11               cv148  RT @Dipikak74365413: @Sushant_SRMagic @PMOIndi...
# 12       amarskadri123  RT @Sassy_Hindu: J&amp;K: The ASI objects to a...
# 13       asn_deepthink  RT @Sassy_Hindu: J&amp;K: The ASI objects to a...
# ...                ...                                                ...
# 21983   YasmeenAlQedwa  RT @NadiSaadeh: An entire nation in grief. Ren...
# 21988         mmaher70  RT @WASoutlooks: Police confirm two 11-year-ol...
# 21993    BelfastBranch  RT @kamaufranklin: Breaking News: The New Jers...
# ...

# %%
dfen = dfen.drop_duplicates(subset='cleaned_tweets', keep='first')
dfen
# Out:
#                   User                                              Tweet  \
# 0          Ephraim0324  RT @dna: #Cannes2022 | #HinaKhan to return to ...
# 1       Moonsroofindia  Farah Khan is funny. “Khaali Peeli,” which Ana...
# 2      janisarSSR_2020  RT @Dipikak74365413: @ATUL7735 @Jannat_Firdous...
# 3               ls2008  RT @Sassy_Hindu: J&amp;K: The ASI objects to a...
# 4         imtruelegend  RT @Ashish81618033: @AdvAshutoshBJP I think ne...
# ...                ...                                                ...
# 21992   JuliusFlywheel  RT @redrabbleroz: I honestly still cannot get ...
# 21995  gordonm25443977  RT @toryman1979: https://t.co/QDwRYKgtm7\nTwin...
# 21997     phorlerkemii  RT @Gistloversblog1: The comment I was looking...
# 21998  Yashika_SidNaaz  RT @filmibeat: Tejasswi Prakash, Shehnaaz Gill...
# 21999        WediRaya7  RT @E2buddy1: On this #MothersDay2022 Tigrayan...
#
#                                           cleaned_tweets
# ...

# %%
# !pip install deep_translator
# Out:
# ...
#      |████████████████████████████████| 128 kB 13.0 MB/s
# ...
#   Attempting uninstall: beautifulsoup4
#     Found existing installation: beautifulsoup4 4.6.3
#     Uninstalling beautifulsoup4-4.6.3:
#       Successfully uninstalled beautifulsoup4-4.6.3
# ...

# %%
# !pip install transformers
# Out:
# ...
#      |████████████████████████████████| 4.0 MB 12.4 MB/s
# ...
#      |████████████████████████████████| 596 kB 39.9 MB/s
# ...
#      |████████████████████████████████| 77 kB 3.3 MB/s
# ...
#      |████████████████████████████████| 880 kB 40.4 MB/s
# ...
#      |████████████████████████████████| 6.6 MB 35.3 MB/s
# ...
#   Created wheel for sacremoses: filename=sacremoses-0.0.53-py3-none-any.whl size=895260 sha256=3621814f460572fc032e547a249c0a17029ba44058ebc2c77014a70931aff611
#   Stored in directory: /root/.cache/pip/wheels/87/39/dd/a83eeef36d0bf98e7a4d1933a4ad2d660295a40613079bafc9
# Successfully built sacremoses
# ...
#   Attempting uninstall: pyyaml
#     Found existing installation: PyYAML 3.13
#     Uninstalling PyYAML-3.13:
#       Successfully uninstalled PyYAML-3.13
# ...

# %%
# !pip install sentencepiece
# Out:
# ...
#      |████████████████████████████████| 1.2 MB 10.0 MB/s
# ...

# %% [markdown]
# Labelling the sentiments of each tweets using teransformers

# %%
from transformers import AutoTokenizer, AutoModelForSequenceClassification
from scipy.special import softmax

# %%
roberta = "cardiffnlp/twitter-xlm-roberta-base-sentiment"

# %%
model = AutoModelForSequenceClassification.from_pretrained(roberta)
tokenizer = AutoTokenizer.from_pretrained(roberta)
# Out:
# Downloading:   0%|          | 0.00/841 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.04G [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/4.83M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/150 [00:00<?, ?B/s]

# %%
def LabelData(tweet_proc):
    
    encoded_tweet = tokenizer(tweet_proc, return_tensors='pt')
    output = model(**encoded_tweet)
    
    scores = output[0][0].detach().numpy()
    scores = softmax(scores)
    
    scores_dict = {'Negative' : scores[0], 'Neutral' : scores[1],'Positive' : scores[2] }
    label = max(zip(scores_dict.values(), scores_dict.keys()))[1]
    
    print(tweet_proc,'->->->->',label)
    return label

dfen['target'] = dfen['cleaned_tweets'].apply(LabelData)
dfen
# Out:
# Streaming output truncated to the last 5000 lines.
# RT  🚨 We need to Raise the Vibration here on twtr for a little bit Share a song meme or inspirational quote that lifts you up… ->->->-> Positive
#  Thats why a meme coin as WiKicat can help you savage this check  buddy ✔️smartest deflationary meme token on BSC  ✔️ tax ✔️ Fair launch  ✔️ ownership renounced   ✔️Liquidity pool locked forever  wkc wikicatcoin wikicat   ->->->-> Positive
#  Nice meme picture PAW’fam ->->->-> Positive
# RT  🚨Meme Competition🚨  Calling all the creatives out there The top  GENOS memes will win  each  Rules ✅Must be original… ->->->-> Positive
# RT  Arrogance is our lifestyle but Haughties Family first ❤️‍🩹  Thanks to  Haughty PickleRick for this meme 🤏🏼  WEAREHA… ->->->-> Positive
# RT  I remember paying  for trades on uniswap not even that long ago Weve come so far its possible to have discounts on… ->->->-> Neutral
# RT   Has good meme potential  ->->->-> Positive
# ...

# %%
import codecs
from deep_translator import GoogleTranslator

def translate(text):
    return GoogleTranslator(source='auto', target='en').translate(text)

dfhi['translated'] = dfhi['cleaned_tweets'].apply(translate)
dfhi
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   import sys
#                   User                                              Tweet  \
# 0        TanseemHaider  RT @aajtak: जैकलीन फर्नांडीस ने कोर्ट से 15 दि...
# 1       sanjayyadav782  RT @OpIndia_in: ‘बॉलीवुड मुझे अफॉर्ड नहीं कर स...
# 2         chetanjoshi_  RT @thepaltan_: संवेदनशील मुद्दों पर सृजनात्मक...
# 3           thepaltan_  संवेदनशील मुद्दों पर सृजनात्मक प्रहार करता सिन...
# 4         RajivSanatni  RT @rowdy_pandit: 💥जब दिखेगा तभी तो बिकेगा!!🤓🙂...
# ...                ...                                                ...
# 21983  rajkuma97966159  RT @SudarshanNewsTV: संजय राउत को पोपट बताते ब...
# ...

# %%
def LabelData(tweet_proc):
    
    encoded_tweet = tokenizer(tweet_proc, return_tensors='pt')
    output = model(**encoded_tweet)
    
    scores = output[0][0].detach().numpy()
    scores = softmax(scores)
    
    scores_dict = {'Negative' : scores[0], 'Neutral' : scores[1],'Positive' : scores[2] }
    label = max(zip(scores_dict.values(), scores_dict.keys()))[1]
    
    print(tweet_proc,'->->->->',label)
    return label

dfhi['target'] = dfhi['translated'].apply(LabelData)
# Out:
# Streaming output truncated to the last 5000 lines.
# Gujarat Titans won the toss and elected to bat GTvsLSG LSGvGT IPL GujaratTitans LucknowSuperGiants toss Playing ->->->-> Neutral
# LSG vs GT Live Gujarat won the toss and batted first against Lucknow. IPL LSGvsGT GTvLSG ->->->-> Neutral
# LSGvsGT Rahul Pandya Live in IPL Points Table Top Teams ->->->-> Neutral
# Daniel Vettori RishabhPant RaviShastri DelhiCapitals DanielVettori IPL ->->->-> Neutral
# Kamal Haasan ka Dasavatharam dekhi hai ->->->-> Neutral
# Jasprit Bumrah got proud after opening the first paw in IPL and stopped speaking critics with his words IPL IPL MI JaspritBumrah TrendingNews cricket ->->->-> Positive
# Bumrah taught how to bowl on DY Patil's pitch Cummins told how to bowl a match winning spell jaspritbumrah mumbaiindians kolkataknightriders ipl indianpremierleague ipl cricket patcummins MIvsKKR KKRvsMI ->->->-> Neutral
# ...

# %%
dfhi
# Out:
#                   User                                              Tweet  \
# 0        TanseemHaider  RT @aajtak: जैकलीन फर्नांडीस ने कोर्ट से 15 दि...
# 1       sanjayyadav782  RT @OpIndia_in: ‘बॉलीवुड मुझे अफॉर्ड नहीं कर स...
# 2         chetanjoshi_  RT @thepaltan_: संवेदनशील मुद्दों पर सृजनात्मक...
# 3           thepaltan_  संवेदनशील मुद्दों पर सृजनात्मक प्रहार करता सिन...
# 4         RajivSanatni  RT @rowdy_pandit: 💥जब दिखेगा तभी तो बिकेगा!!🤓🙂...
# ...                ...                                                ...
# 21983  rajkuma97966159  RT @SudarshanNewsTV: संजय राउत को पोपट बताते ब...
# 21984   PredeepSharma2  RT @SatlokChannel: प्रत्येक वर्ष 25 अप्रैल को ...
# 21987   PredeepSharma2  RT @SatlokChannel: संत रामपाल जी महाराज के अनु...
# 21988   PredeepSharma2  RT @SatlokChannel: Twitter कम्पनी ने Elon musk...
# 21991     ZeeBiharNews  #Purnea- बाल सुधार गृह से 11 बाल कैदी फरार | #...
#
#                                           cleaned_tweets  \
# ...

# %%
dfhi.to_csv('twitter_labelled-hi.csv', index=False)
dfhi
# Out:
#                   User                                              Tweet  \
# 0        TanseemHaider  RT @aajtak: जैकलीन फर्नांडीस ने कोर्ट से 15 दि...
# 1       sanjayyadav782  RT @OpIndia_in: ‘बॉलीवुड मुझे अफॉर्ड नहीं कर स...
# 2         chetanjoshi_  RT @thepaltan_: संवेदनशील मुद्दों पर सृजनात्मक...
# 3           thepaltan_  संवेदनशील मुद्दों पर सृजनात्मक प्रहार करता सिन...
# 4         RajivSanatni  RT @rowdy_pandit: 💥जब दिखेगा तभी तो बिकेगा!!🤓🙂...
# ...                ...                                                ...
# 21983  rajkuma97966159  RT @SudarshanNewsTV: संजय राउत को पोपट बताते ब...
# 21984   PredeepSharma2  RT @SatlokChannel: प्रत्येक वर्ष 25 अप्रैल को ...
# 21987   PredeepSharma2  RT @SatlokChannel: संत रामपाल जी महाराज के अनु...
# 21988   PredeepSharma2  RT @SatlokChannel: Twitter कम्पनी ने Elon musk...
# 21991     ZeeBiharNews  #Purnea- बाल सुधार गृह से 11 बाल कैदी फरार | #...
#
#                                           cleaned_tweets  \
# ...

# %%
dfen.to_csv('twitter_labelled-en.csv', index=False)
dfen
# Out:
#                   User                                              Tweet  \
# 0          Ephraim0324  RT @dna: #Cannes2022 | #HinaKhan to return to ...
# 1       Moonsroofindia  Farah Khan is funny. “Khaali Peeli,” which Ana...
# 2      janisarSSR_2020  RT @Dipikak74365413: @ATUL7735 @Jannat_Firdous...
# 3               ls2008  RT @Sassy_Hindu: J&amp;K: The ASI objects to a...
# 4         imtruelegend  RT @Ashish81618033: @AdvAshutoshBJP I think ne...
# ...                ...                                                ...
# 21992   JuliusFlywheel  RT @redrabbleroz: I honestly still cannot get ...
# 21995  gordonm25443977  RT @toryman1979: https://t.co/QDwRYKgtm7\nTwin...
# 21997     phorlerkemii  RT @Gistloversblog1: The comment I was looking...
# 21998  Yashika_SidNaaz  RT @filmibeat: Tejasswi Prakash, Shehnaaz Gill...
# 21999        WediRaya7  RT @E2buddy1: On this #MothersDay2022 Tigrayan...
#
#                                           cleaned_tweets    target
# ...

# %%
dfhi.pop('translated')
# Out:
# 0        RT Jacqueline Fernandez seeks permission from ...
# 1        RT 'Bollywood can't afford me doesn't want to ...
# 2        RT Cinema making a creative attack on sensitiv...
# 3        Cinema giving creative strikes on sensitive is...
# 4        RT will sell when you see it Simple logic boll...
#                                ...
# 21983    Navneet Rana said that RT Sanjay Raut is a Pop...
# 21984    RT World Malaria Day is observed every year on...
# 21987    The followers of RT Sant Rampal Ji Maharaj kee...
# 21988    RT Twitter The company accepted the offer of E...
# 21991    Child prisoner absconding from Purnea juvenile...
# Name: translated, Length: 10775, dtype: object

# %%
pd.concat([dfhi,dfen]).to_csv('twitter_data_final.csv', index=False )
